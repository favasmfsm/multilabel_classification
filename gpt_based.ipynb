# %%
import pandas as pd
import re
import ast
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer
import numpy as np
from transformers import AutoTokenizer, AutoModel
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import accuracy_score, classification_report
from openai import OpenAI
import json

# %%
df = pd.read_csv("labeled_data.csv")
label_filter = ["Restatements", "Errors", "Part III", "Exhibit 101", "Signatures"]
print(label_filter)
# Out:
# ['Restatements', 'Errors', 'Part III', 'Exhibit 101', 'Signatures']

# %%
def convert_to_list(entry):
    try:
        return ast.literal_eval(entry)
    except:
        pass

df['labels'] = df.labels.apply(convert_to_list)
df['rule_based_label'] = df.rule_based_label.apply(convert_to_list)

# %%
def is_in_filtered(labels):
    for label in labels:
        if label not in label_filter:
            return False
    return True

print(df.shape)
df = df[df.labels.apply(lambda x: is_in_filtered(x))]
print(df.shape)
# Out:
# (1192, 5)
# (638, 5)

# %%
df_sampled = df.sample(20, random_state=42)
df_sampled.head()
# Out:
#                       file_name  \
# 536  q_0001193125-12-359187.txt
# 501  k_0001214659-15-003301.txt
# 36   k_0001144204-09-022929.txt
# 884  k_0001548123-13-000255.txt
# 902  q_0001193125-09-016547.txt
#
#                                          expl_note_gpt          labels  \
# 536  The paragraph that talks about the purpose of ...   [Exhibit 101]
# 501  The purpose of this Form 10-K/A is to provide ...      [Part III]
# 36   The purpose of this Amendment No. 1 on Form 10...      [Part III]
# 884  The purpose of this amended Form 10-K is to re...  [Restatements]
# 902  The Form 10-Q/A is being filed solely to corre...        [Errors]
#
#                                              expl_note        rule_based_label
# 536  EXPLANATORY NOTE  This Amendment No. 1 to the ...           [Exhibit 101]
# 501  EXPLANATORY NOTE\n\n Wright Investors' Service...              [Part III]
# 36   EXPLANATORY\nNOTE\n\nThis\nAmendment No. 1 on ...              [Part III]
# 884  EXPLANATORY NOTE  During the preparation of th...          [Restatements]
# 902  Explanatory Note  The Form 10-Q/A is being fil...  [Restatements, Errors]

# %%
# Step 2: Encode `rule_based_label` and `labels` into arrays of size 11
mlb = MultiLabelBinarizer()
rule_based_label_encoded = mlb.fit_transform(df_sampled['labels'])
labels_encoded = mlb.transform(df_sampled['rule_based_label'])
print(mlb.classes_)
# Out:
# ['Errors' 'Exhibit 101' 'Part III' 'Restatements']
# /Users/ihjasahammedm/miniconda3/envs/hf/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:900: UserWarning: unknown class(es) ['None of the above'] will be ignored
#   warnings.warn(

# %%
print('Accuracy:', accuracy_score(labels_encoded, rule_based_label_encoded))
print('Classification Report:')
print(classification_report(labels_encoded, rule_based_label_encoded, target_names=mlb.classes_))
# Out:
# Accuracy: 0.65
# Classification Report:
#               precision    recall  f1-score   support
#
#       Errors       1.00      0.57      0.73         7
#  Exhibit 101       0.75      1.00      0.86         3
#     Part III       1.00      1.00      1.00         4
# Restatements       0.78      0.78      0.78         9
#
#    micro avg       0.86      0.78      0.82        23
#    macro avg       0.88      0.84      0.84        23
# weighted avg       0.88      0.78      0.81        23
#  samples avg       0.85      0.75      0.78        23
# /Users/ihjasahammedm/miniconda3/envs/hf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
client = OpenAI() # set export OPENAI_API_KEY='your-api-key-here' on terminal before opening jupyter lab

def gpt_annotation(row, model="gpt-4o", temperature=0):
    x = row['expl_note_gpt']
    response = client.chat.completions.create(
      model="gpt-3.5-turbo",
      messages=[
         {
          "role": "system",
          "content": [
            {
              "type": "text",
              "text": "You are an expert in SEC filings. Your task is to tag the given SEC note based on its content. Each note should be tagged with one or more appropriate tags from the provided list. Most notes will have a single tag, but there may be cases where two or three tags are necessary. More than three tags will be rare.\n\nTags should be strictly chosen from the following list given in backticks:\n```\nRestatements\nErrors\nPart III\nExhibit 101\nSignatures\n```\n\nHere are the definitions of each tag:\n\nRestatements:\nan amendment used to restate or for restatement. Example: filing an Amendment No. 1 on Form 10-Q/A to amend and restate our unaudited condensed consolidated financial statements\n\nErrors:\nan amendment to correct an error or miscalculation. Example: This amendment is being filed to correct the Company's authorized common stock, a calculation error in Footnote 8\\n \n\nPart III:\nAmendments that are done to just provide information in Part III of the original filing. Here is an example: \"being filed to furnish the information required by Items 10, 11, 12, 13 and 14 of Part III of the Original Filing\"\n\nExhibit 101:\namendment that are done to provide Exhibit 101. Example: The purpose of this Amendment No. 1 to the Old Republic International Corporation (\"Old Republic\") Quarterly Report on Form 10-Q for the quarterly period ended June 30, 2010, filed with the Securities and Exchange Commission on August 9, 2010, is to furnish Exhibit 101 to the Form 10-Q\n\nSignatures:\nAmendments that are filed because the original didn't have the signatures of the executives. Here is an example: RELM Wireless Corporation hereby amends its Quarterly Report on Form 10-Q for the quarterly period ended March 31, 2012, filed on May 9, 2012, solely for the purpose of including the conformed signatures to the Form 10-Q on page 16, which were inadvertently omitted from the original filing.\n\nYou also need to reason why you have picked a particular tag. The reason should justify the tag and mention which part of the note is relevant to the tag. \n\nOutput format is JSON:\n[\n    {\n        \"reason\": \"This is the reason why I choose tag 1\",\n        \"tag\": \"tag 1\"\n    },\n    //similarly other tags\n]\n\nReturn an empty list if none of the given tags are applicable to the note.\n"
            }
          ]
        },
        {
          "role": "user",
          "content": [
            {
              "type": "text",
              "text": x
            }
          ]
        }
      ],
      temperature=temperature,
      max_tokens=4095,
      top_p=1,
      frequency_penalty=0,
      presence_penalty=0
    )
    print('------')
    print(x)
    print(response.choices[0].message.content)
    json_resp = json.loads(response.choices[0].message.content)
    labels = []
    for item in json_resp:
        labels.append(item['tag'])
    print(labels)
    if labels != row['labels']:
        print(row['labels'])
        print(row['rule_based_label'])
        # print(row['expl_note'])
    print('------')
    return labels

# gpt_annotation(df_sampled.iloc[0, :])

# %%
df_sampled['labels_gpt3'] = df_sampled.apply(lambda x: gpt_annotation(x), axis=1)
# Out:
# ------
# The paragraph that talks about the purpose of the amendment/form in the given SEC note is:
#
# "This Amendment No. 1 to the Quarterly Report on Form 10-Q (the "Form 10-Q") of Wireless Ronin Technologies, Inc. for the period ended June 30, 2012 is being filed solely to furnish Exhibit 101 to the Form 10-Q in accordance with Rule 405 of Regulation S-T. Exhibit 101 to the Form 10-Q provides the consolidated financial statements and related notes from the Form 10-Q formatted in XBRL (eXtensible Business Reporting Language). No other changes have been made to the Form 10-Q."
# [
#     {
#         "reason": "The note specifically mentions that the purpose of the amendment is to furnish Exhibit 101 to the Form 10-Q, which is a clear indication for the Exhibit 101 tag.",
#         "tag": "Exhibit 101"
#     }
# ]
# ['Exhibit 101']
# ------
# ------
# The purpose of this Form 10-K/A is to provide the information required to be disclosed in Part III, Items 10 through 14 and updates the information contained in Part IV, Item 15. As a result of this amendment, the Company is filing as exhibits to this Form 10-K/A the certifications required under Section 302 of the Sarbanes-Oxley Act of 2002. Because no financial statements are contained within this Form 10-K/A, the Company is not including certifications pursuant to Section 906 of the Sarbanes-Oxley Act of 2002.
# []
# []
# ['Part III']
# ['Part III']
# ------
# ------
# The purpose of this Amendment No. 1 on Form 10-K/A (this "Amendment") to the Annual Report on Form 10-K of O.I. Corporation is being filed solely for the purpose of including the information required by Part III, Items 10-14 of Form 10-K. This information was previously omitted from the Form 10-K in reliance on General Instruction G to Form 10-K which provides that registrants may incorporate by reference certain information from a definitive proxy statement filed with the Securities Exchange Commission within 120 days after the end of the fiscal year. The reference on the cover of the Annual Report on Form 10-K to the incorporation by reference of the registrant's definitive proxy statement into Part III of the Annual Report is hereby deleted. This report is limited in scope to the items identified above and should be read in conjunction with the Original Filing.
# [
#     {
#         "reason": "The note specifically mentions that the purpose of the amendment is to include information required by Part III, Items 10-14 of Form 10-K, which justifies tagging it as Part III.",
#         "tag": "Part III"
#     }
# ]
# ['Part III']
# ------
# ------
# The purpose of this amended Form 10-K is to restate the financial statements for the year ended December 31, 2012 to reflect the proper revenues and related adjustments.
#
# [
#     {
#         "reason": "The note explicitly mentions that the purpose of the amendment is to restate the financial statements, which is a clear indication of a restatement.",
#         "tag": "Restatements"
#     }
# ]
# ['Restatements']
# ------
# ------
# The Form 10-Q/A is being filed solely to correct the omission of certain language required under the Certification in the World Monitor Trust II – Series D's Form 10-Q previously filed on August 7, 2008 and amended on February 2, 2009, which are restated in their entirety herewith.
#
# [
#     {
#         "reason": "The note mentions that the Form 10-Q/A is being filed solely to correct the omission of certain language, which indicates that it is an amendment to correct an error.",
#         "tag": "Errors"
#     },
#     {
#         "reason": "The note also states that the Form 10-Q previously filed on August 7, 2008, and amended on February 2, 2009, are restated in their entirety herewith, indicating a restatement.",
#         "tag": "Restatements"
#     }
# ]
# ['Errors', 'Restatements']
# ['Errors']
# ['Restatements', 'Errors']
# ------
# ------
# The purpose of this Amendment No. 1 is to add Suneil Parulekar, our Senior Vice President, Worldwide Marketing and Sales, as a named executive officer for purposes of Part III, Item 11 ("Executive Compensation") and the "Security Ownership of Management" table in Item 12 ("Security Ownership of Certain Beneficial Owners and Management and Related Stockholder Matters"). We have also corrected minor typographical and formatting errors.
# [
#     {
#         "reason": "The note is specifically mentioning that the purpose of the filing is to add a named executive officer for Part III and to correct minor typographical errors.",
#         "tag": "Part III"
#     },
#     {
#         "reason": "The note states that minor typographical errors have been corrected, which falls under the category of Errors.",
#         "tag": "Errors"
#     }
# ]
# ['Part III', 'Errors']
# ['Errors', 'Part III']
# ['Errors', 'Part III']
# ------
# ------
# The registrant is filing this Amendment No. 1 to its Quarterly Report on Form 10-Q for the quarterly period ended June 30, 2008, which was originally filed with the Securities and Exchange Commission ("SEC") on August 19, 2008 ("Original Form 10-Q"), to amend Part 1 Financial Information – Item 1 "Financial Statements" and Item 2 "Management's Discussion and Analysis of Financial Condition and Results of Operations" ("MD&A). Additionally, one typographical error in each of Part 1 Financial Information – Item 4 "Controls and Procedures" and in Part 2 Other Information - Item 1A "Risk Factors" respectively has been corrected.
#
# []
# []
# ['Restatements']
# ['Errors']
# ------
# ------
# The purpose of this Form 10-K/A is to correct the front page of the Form 10-K for the fiscal year ended December 31, 2004, previously filed with the Securities and Exchange Commission. The correction involves the incorrect statement that there were 23,531,229 shares of the registrant's common stock outstanding as of January 31, 2005, when the correct number was 19,261,652 shares.
# [
#     {
#         "reason": "The note mentions that the purpose of the filing is to correct an error in the number of shares of common stock outstanding, which aligns with the definition of the Errors tag.",
#         "tag": "Errors"
#     }
# ]
# ['Errors']
# ------
# ------
# The sole purpose of this Form 10-Q/A is to furnish the interactive data files from our Form 10-Q formatted in Extensible Business Reporting Language (XBRL)
# []
# []
# ['Exhibit 101']
# ['Exhibit 101']
# ------
# ------
# The purpose of this Amendment is to amend and restate the following Items in the Original Report as amended including updating the Title Page:
#
# []
# []
# ['Restatements']
# ['Restatements']
# ------
# ------
# The purpose of this Amendment is to restate the financial statements of FinTech Acquisition Corp. V for the year ended December 31, 2020, to correct an error identified in the Original Financial Statements related to the recording of Class A common stock subject to possible redemption. Management has determined that the shares of Class A common stock underlying the units issued during the initial public offering can be redeemed or become redeemable, leading to a reclassification error between temporary equity and permanent equity. This restatement also includes changes to the earnings per share calculation to allocate income and losses pro rata between the two classes of shares.
#
# [
#     {
#         "reason": "The note explicitly mentions that the purpose of the Amendment is to restate the financial statements to correct an error identified in the Original Financial Statements",
#         "tag": "Restatements"
#     },
#     {
#         "reason": "The note specifies that the restatement is to correct an error related to the recording of Class A common stock, justifying the 'Errors' tag",
#         "tag": "Errors"
#     }
# ]
# ['Restatements', 'Errors']
# ['Restatements']
# ['Restatements', 'Errors']
# ------
# ------
# The purpose of this Amendment No. 2 on Form 10-Q/A to the Original Form 10-Q (the "Amendment No. 2") (i) includes the entire periodic report originally filed with the Original Form 10-Q, (ii) amends and restates Note 4 (Private Placement) of the Notes to the Company's Condensed Financial Statements included therein and (iii) includes updated certifications by our Chief Executive Officer and Chief Financial Officer as required by Item 601 of Regulation S-K.
#
# []
# []
# ['Restatements']
# ['Restatements']
# ------
# ------
# Accordingly, this amended 10-Q is filed to correct the manner in which the Company accounted for the lease. See Note I. Restatement, to the accompanying financial statements, for further information.
# [
#     {
#         "reason": "The note mentions that the amended 10-Q is filed to correct the accounting treatment, which falls under restatements.",
#         "tag": "Restatements"
#     }
# ]
# ['Restatements']
# ------
# ------
# The purpose of this Amendment No. 1 on Form 10-K/A is to provide the information required by Part III of Form 10-K, which was previously omitted from the Original Filing in reliance on General Instruction G(3) to Form 10-K. Additionally, this Form 10-K/A amends and restates specific items in their entirety as required by Rule 12b-15 under the Exchange Act of 1934.
#
# [
#     {
#         "reason": "The note mentions amending and restating specific items in their entirety as required by Rule 12b-15 under the Exchange Act of 1934, which indicates a restatement.",
#         "tag": "Restatements"
#     },
#     {
#         "reason": "The note states that the purpose of the amendment is to provide the information required by Part III of Form 10-K, which was previously omitted from the Original Filing, indicating a need to provide information in Part III.",
#         "tag": "Part III"
#     }
# ]
# ['Restatements', 'Part III']
# ['Part III']
# ['Restatements', 'Part III']
# ------
# ------
# The Company is filing this Amendment No. 3 to its Form 10Q for the fiscal quarter ended June 30, 2011 originally filed with the Securities and Exchange Commission on August 19, 2011 (the "Original Filing") and subsequently amended on September 14, 2011, and March 23, 2012. As previously reported by the Company on a Form 8-K filed with the Commission on September 20, 2012, on September 19, 2012, the Company changed its fiscal year end from March 31st to December 31st, commencing on December 31, 2012. Prior to this change, the Company's subsidiaries, with the exception of SD Holdings, Ltd. had a December 31st fiscal year end and in reporting the Company's financial statements, the Company, incorrectly applied of Rule 3A-02 ("the 93-day rule") promulgated under Regulation S-X by consolidating those subsidiaries without any adjustments for
#
# []
# []
# ['Restatements']
# ['None of the above']
# ------
# ------
# The purpose of this Amendment No. 2 to the Annual Report on Form 10-K of Oaktree Acquisition Corp. II is to restate certain items in its previous filings, specifically related to the accounting classification of its outstanding Class A ordinary shares issued as part of the initial public offering. The Company has re-evaluated its application of ASC 480-10-S99-3A and determined that all of the Public Shares should be classified as temporary equity, leading to a restatement of earnings per share calculation to allocate income and losses pro rata between the two classes of shares.
#
# [
#     {
#         "reason": "The note mentions that the purpose of the amendment is to restate certain items in its previous filings related to accounting classification, leading to a restatement of earnings per share calculation. This aligns with the definition of restatements.",
#         "tag": "Restatements"
#     }
# ]
# ['Restatements']
# ------
# ------
# The purpose of this Amendment No. 1 to Bonds.com Group, Inc.'s annual report filed on Form 10-K/A is to correct the Company's inadvertent omission of a portion of the execution dates in the Certifications previously filed.
# []
# []
# ['Errors']
# ['Errors']
# ------
# ------
# The purpose of this Amendment No. 1 to the Annual Report of Meganet Corporation (the "Company") on Form 10-K for the fiscal year ended March 31, 2013, filed with the Securities and Exchange Commission on September 11, 2014 (the "Form 10-K"), is to furnish Exhibit 101 to the Form 10-K in accordance with Rule 405 of Regulation S-T. Exhibit 101 to this report provides the financial statements and related notes from the Form 10-K formatted in XBRL (eXtensible Business Reporting Language).
# []
# []
# ['Exhibit 101']
# ['Exhibit 101']
# ------
# ------
# The sole purpose of this Amendment to the Registrant's Quarterly Report on Form 10-Q for the period ended March 31, 2012 (the "10-Q"), is to furnish the Interactive Data File exhibits required by Item 601(b)(101) of Regulation S-K. No other changes have been made to the 10-Q, and this Amendment has not been updated to reflect events occurring subsequent to the filing of the 10-Q.
# [
#     {
#         "reason": "The note is specifically mentioning that the purpose of the amendment is to furnish Exhibit 101, which is required by Item 601(b)(101) of Regulation S-K.",
#         "tag": "Exhibit 101"
#     }
# ]
# ['Exhibit 101']
# ------
# ------
# The purpose of this amendment is to amend and restate Part I, Items 1 and 2 "Financial Information" and Part II, Item 6 "Exhibits and Reports on Form 8-K" of the Form 10-Q as a result of a restatement of the Company's balance sheet and operating results for the year ended December 31, 1998. This restatement is to reduce acquisition-related reserves and charges by $31.0 million and provide additional disclosures related to the Company's 1998 acquisition of Howmedica, following discussions with the Securities and Exchange Commission ("SEC").
# [
#     {
#         "reason": "The note mentions a restatement of the Company's balance sheet and operating results for the year ended December 31, 1998, to reduce acquisition-related reserves and charges by $31.0 million. This aligns with the definition of restatements.",
#         "tag": "Restatements"
#     }
# ]
# ['Restatements']
# ------

# %%
df_sampled['labels_gpt4o'] = df_sampled.apply(lambda x: gpt_annotation(x, model='gpt-4o'), axis=1)
# Out:
# ------
# The paragraph that talks about the purpose of the amendment/form in the given SEC note is:
#
# "This Amendment No. 1 to the Quarterly Report on Form 10-Q (the "Form 10-Q") of Wireless Ronin Technologies, Inc. for the period ended June 30, 2012 is being filed solely to furnish Exhibit 101 to the Form 10-Q in accordance with Rule 405 of Regulation S-T. Exhibit 101 to the Form 10-Q provides the consolidated financial statements and related notes from the Form 10-Q formatted in XBRL (eXtensible Business Reporting Language). No other changes have been made to the Form 10-Q."
# [
#     {
#         "reason": "The note specifically mentions that the purpose of the amendment is to furnish Exhibit 101 to the Form 10-Q, which is a clear indication for tagging it as Exhibit 101.",
#         "tag": "Exhibit 101"
#     }
# ]
# ['Exhibit 101']
# ------
# ------
# The purpose of this Form 10-K/A is to provide the information required to be disclosed in Part III, Items 10 through 14 and updates the information contained in Part IV, Item 15. As a result of this amendment, the Company is filing as exhibits to this Form 10-K/A the certifications required under Section 302 of the Sarbanes-Oxley Act of 2002. Because no financial statements are contained within this Form 10-K/A, the Company is not including certifications pursuant to Section 906 of the Sarbanes-Oxley Act of 2002.
# [
#     {
#         "reason": "The note is specifically mentioning that the purpose of the amendment is to provide information required in Part III of the original filing.",
#         "tag": "Part III"
#     },
#     {
#         "reason": "The note states that the Company is filing exhibits to provide certifications required under Section 302 of the Sarbanes-Oxley Act of 2002.",
#         "tag": "Exhibit 101"
#     }
# ]
# ['Part III', 'Exhibit 101']
# ['Part III']
# ['Part III']
# ------
# ------
# The purpose of this Amendment No. 1 on Form 10-K/A (this "Amendment") to the Annual Report on Form 10-K of O.I. Corporation is being filed solely for the purpose of including the information required by Part III, Items 10-14 of Form 10-K. This information was previously omitted from the Form 10-K in reliance on General Instruction G to Form 10-K which provides that registrants may incorporate by reference certain information from a definitive proxy statement filed with the Securities Exchange Commission within 120 days after the end of the fiscal year. The reference on the cover of the Annual Report on Form 10-K to the incorporation by reference of the registrant's definitive proxy statement into Part III of the Annual Report is hereby deleted. This report is limited in scope to the items identified above and should be read in conjunction with the Original Filing.
# [
#     {
#         "reason": "The note specifically mentions that the purpose of the amendment is to include information required by Part III, Items 10-14 of Form 10-K, which justifies tagging it as Part III.",
#         "tag": "Part III"
#     }
# ]
# ['Part III']
# ------
# ------
# The purpose of this amended Form 10-K is to restate the financial statements for the year ended December 31, 2012 to reflect the proper revenues and related adjustments.
#
# [
#     {
#         "reason": "The note explicitly mentions that the purpose of the amendment is to restate the financial statements, which aligns with the definition of the Restatements tag.",
#         "tag": "Restatements"
#     }
# ]
# ['Restatements']
# ------
# ------
# The Form 10-Q/A is being filed solely to correct the omission of certain language required under the Certification in the World Monitor Trust II – Series D's Form 10-Q previously filed on August 7, 2008 and amended on February 2, 2009, which are restated in their entirety herewith.
#
# [
#     {
#         "reason": "The note mentions that the Form 10-Q/A is being filed solely to correct an omission, which indicates an error correction.",
#         "tag": "Errors"
#     },
#     {
#         "reason": "The note also mentions that the Form 10-Q/A is being restated in its entirety, indicating a restatement.",
#         "tag": "Restatements"
#     }
# ]
# ['Errors', 'Restatements']
# ['Errors']
# ['Restatements', 'Errors']
# ------
# ------
# The purpose of this Amendment No. 1 is to add Suneil Parulekar, our Senior Vice President, Worldwide Marketing and Sales, as a named executive officer for purposes of Part III, Item 11 ("Executive Compensation") and the "Security Ownership of Management" table in Item 12 ("Security Ownership of Certain Beneficial Owners and Management and Related Stockholder Matters"). We have also corrected minor typographical and formatting errors.
# [
#     {
#         "reason": "The note is specifically mentioning that the purpose of the filing is to add a named executive officer for Part III and to correct minor errors, which aligns with the 'Part III' and 'Errors' tags.",
#         "tag": "Part III"
#     },
#     {
#         "reason": "The note states that minor typographical and formatting errors have been corrected, which falls under the 'Errors' tag.",
#         "tag": "Errors"
#     }
# ]
# ['Part III', 'Errors']
# ['Errors', 'Part III']
# ['Errors', 'Part III']
# ------
# ------
# The registrant is filing this Amendment No. 1 to its Quarterly Report on Form 10-Q for the quarterly period ended June 30, 2008, which was originally filed with the Securities and Exchange Commission ("SEC") on August 19, 2008 ("Original Form 10-Q"), to amend Part 1 Financial Information – Item 1 "Financial Statements" and Item 2 "Management's Discussion and Analysis of Financial Condition and Results of Operations" ("MD&A). Additionally, one typographical error in each of Part 1 Financial Information – Item 4 "Controls and Procedures" and in Part 2 Other Information - Item 1A "Risk Factors" respectively has been corrected.
#
# []
# []
# ['Restatements']
# ['Errors']
# ------
# ------
# The purpose of this Form 10-K/A is to correct the front page of the Form 10-K for the fiscal year ended December 31, 2004, previously filed with the Securities and Exchange Commission. The correction involves the incorrect statement that there were 23,531,229 shares of the registrant's common stock outstanding as of January 31, 2005, when the correct number was 19,261,652 shares.
# []
# []
# ['Errors']
# ['Errors']
# ------
# ------
# The sole purpose of this Form 10-Q/A is to furnish the interactive data files from our Form 10-Q formatted in Extensible Business Reporting Language (XBRL)
# []
# []
# ['Exhibit 101']
# ['Exhibit 101']
# ------
# ------
# The purpose of this Amendment is to amend and restate the following Items in the Original Report as amended including updating the Title Page:
#
# []
# []
# ['Restatements']
# ['Restatements']
# ------
# ------
# The purpose of this Amendment is to restate the financial statements of FinTech Acquisition Corp. V for the year ended December 31, 2020, to correct an error identified in the Original Financial Statements related to the recording of Class A common stock subject to possible redemption. Management has determined that the shares of Class A common stock underlying the units issued during the initial public offering can be redeemed or become redeemable, leading to a reclassification error between temporary equity and permanent equity. This restatement also includes changes to the earnings per share calculation to allocate income and losses pro rata between the two classes of shares.
#
# [
#     {
#         "reason": "The note explicitly mentions that the purpose of the Amendment is to restate the financial statements to correct an error identified in the Original Financial Statements.",
#         "tag": "Restatements"
#     },
#     {
#         "reason": "The note specifies that the Amendment is to correct an error related to the recording of Class A common stock, justifying the 'Errors' tag.",
#         "tag": "Errors"
#     }
# ]
# ['Restatements', 'Errors']
# ['Restatements']
# ['Restatements', 'Errors']
# ------
# ------
# The purpose of this Amendment No. 2 on Form 10-Q/A to the Original Form 10-Q (the "Amendment No. 2") (i) includes the entire periodic report originally filed with the Original Form 10-Q, (ii) amends and restates Note 4 (Private Placement) of the Notes to the Company's Condensed Financial Statements included therein and (iii) includes updated certifications by our Chief Executive Officer and Chief Financial Officer as required by Item 601 of Regulation S-K.
#
# []
# []
# ['Restatements']
# ['Restatements']
# ------
# ------
# Accordingly, this amended 10-Q is filed to correct the manner in which the Company accounted for the lease. See Note I. Restatement, to the accompanying financial statements, for further information.
# [
#     {
#         "reason": "The note mentions that the amended 10-Q is filed to correct the manner in which the Company accounted for the lease, indicating a restatement of financial statements.",
#         "tag": "Restatements"
#     }
# ]
# ['Restatements']
# ------
# ------
# The purpose of this Amendment No. 1 on Form 10-K/A is to provide the information required by Part III of Form 10-K, which was previously omitted from the Original Filing in reliance on General Instruction G(3) to Form 10-K. Additionally, this Form 10-K/A amends and restates specific items in their entirety as required by Rule 12b-15 under the Exchange Act of 1934.
#
# [
#     {
#         "reason": "The note mentions amending and restating specific items in their entirety as required by Rule 12b-15 under the Exchange Act of 1934, which indicates a restatement.",
#         "tag": "Restatements"
#     },
#     {
#         "reason": "The note states that the purpose of the amendment is to provide the information required by Part III of Form 10-K, which was previously omitted from the Original Filing, indicating a need to provide information in Part III.",
#         "tag": "Part III"
#     }
# ]
# ['Restatements', 'Part III']
# ['Part III']
# ['Restatements', 'Part III']
# ------
# ------
# The Company is filing this Amendment No. 3 to its Form 10Q for the fiscal quarter ended June 30, 2011 originally filed with the Securities and Exchange Commission on August 19, 2011 (the "Original Filing") and subsequently amended on September 14, 2011, and March 23, 2012. As previously reported by the Company on a Form 8-K filed with the Commission on September 20, 2012, on September 19, 2012, the Company changed its fiscal year end from March 31st to December 31st, commencing on December 31, 2012. Prior to this change, the Company's subsidiaries, with the exception of SD Holdings, Ltd. had a December 31st fiscal year end and in reporting the Company's financial statements, the Company, incorrectly applied of Rule 3A-02 ("the 93-day rule") promulgated under Regulation S-X by consolidating those subsidiaries without any adjustments for
#
# []
# []
# ['Restatements']
# ['None of the above']
# ------
# ------
# The purpose of this Amendment No. 2 to the Annual Report on Form 10-K of Oaktree Acquisition Corp. II is to restate certain items in its previous filings, specifically related to the accounting classification of its outstanding Class A ordinary shares issued as part of the initial public offering. The Company has re-evaluated its application of ASC 480-10-S99-3A and determined that all of the Public Shares should be classified as temporary equity, leading to a restatement of earnings per share calculation to allocate income and losses pro rata between the two classes of shares.
#
# [
#     {
#         "reason": "The note mentions that the purpose of the amendment is to restate certain items in previous filings related to accounting classification, leading to a restatement of earnings per share calculation. This aligns with the definition of restatements.",
#         "tag": "Restatements"
#     }
# ]
# ['Restatements']
# ------
# ------
# The purpose of this Amendment No. 1 to Bonds.com Group, Inc.'s annual report filed on Form 10-K/A is to correct the Company's inadvertent omission of a portion of the execution dates in the Certifications previously filed.
# [
#     {
#         "reason": "The note mentions that the purpose of the filing is to correct an error, which is the inadvertent omission of a portion of the execution dates in the Certifications previously filed.",
#         "tag": "Errors"
#     }
# ]
# ['Errors']
# ------
# ------
# The purpose of this Amendment No. 1 to the Annual Report of Meganet Corporation (the "Company") on Form 10-K for the fiscal year ended March 31, 2013, filed with the Securities and Exchange Commission on September 11, 2014 (the "Form 10-K"), is to furnish Exhibit 101 to the Form 10-K in accordance with Rule 405 of Regulation S-T. Exhibit 101 to this report provides the financial statements and related notes from the Form 10-K formatted in XBRL (eXtensible Business Reporting Language).
# [
#     {
#         "reason": "The note is specifically mentioning that the purpose of the amendment is to furnish Exhibit 101 to the Form 10-K, which is a clear indication of providing Exhibit 101.",
#         "tag": "Exhibit 101"
#     }
# ]
# ['Exhibit 101']
# ------
# ------
# The sole purpose of this Amendment to the Registrant's Quarterly Report on Form 10-Q for the period ended March 31, 2012 (the "10-Q"), is to furnish the Interactive Data File exhibits required by Item 601(b)(101) of Regulation S-K. No other changes have been made to the 10-Q, and this Amendment has not been updated to reflect events occurring subsequent to the filing of the 10-Q.
# [
#     {
#         "reason": "The note is specifically mentioning that the purpose of the amendment is to furnish Exhibit 101, which is required by Item 601(b)(101) of Regulation S-K.",
#         "tag": "Exhibit 101"
#     }
# ]
# ['Exhibit 101']
# ------
# ------
# The purpose of this amendment is to amend and restate Part I, Items 1 and 2 "Financial Information" and Part II, Item 6 "Exhibits and Reports on Form 8-K" of the Form 10-Q as a result of a restatement of the Company's balance sheet and operating results for the year ended December 31, 1998. This restatement is to reduce acquisition-related reserves and charges by $31.0 million and provide additional disclosures related to the Company's 1998 acquisition of Howmedica, following discussions with the Securities and Exchange Commission ("SEC").
# [
#     {
#         "reason": "The note mentions a restatement of the Company's balance sheet and operating results for the year ended December 31, 1998, which is a clear indication of a restatement.",
#         "tag": "Restatements"
#     }
# ]
# ['Restatements']
# ------

# %%
df_sampled['labels_gpt4'] = df_sampled.apply(lambda x: gpt_annotation(x, model='gpt-4'), axis=1)
# Out:
# ------
# The paragraph that talks about the purpose of the amendment/form in the given SEC note is:
#
# "This Amendment No. 1 to the Quarterly Report on Form 10-Q (the "Form 10-Q") of Wireless Ronin Technologies, Inc. for the period ended June 30, 2012 is being filed solely to furnish Exhibit 101 to the Form 10-Q in accordance with Rule 405 of Regulation S-T. Exhibit 101 to the Form 10-Q provides the consolidated financial statements and related notes from the Form 10-Q formatted in XBRL (eXtensible Business Reporting Language). No other changes have been made to the Form 10-Q."
# [
#     {
#         "reason": "The note specifically mentions that the purpose of the amendment is to furnish Exhibit 101 to the Form 10-Q, which is a clear indication for the Exhibit 101 tag.",
#         "tag": "Exhibit 101"
#     }
# ]
# ['Exhibit 101']
# ------
# ------
# The purpose of this Form 10-K/A is to provide the information required to be disclosed in Part III, Items 10 through 14 and updates the information contained in Part IV, Item 15. As a result of this amendment, the Company is filing as exhibits to this Form 10-K/A the certifications required under Section 302 of the Sarbanes-Oxley Act of 2002. Because no financial statements are contained within this Form 10-K/A, the Company is not including certifications pursuant to Section 906 of the Sarbanes-Oxley Act of 2002.
# []
# []
# ['Part III']
# ['Part III']
# ------
# ------
# The purpose of this Amendment No. 1 on Form 10-K/A (this "Amendment") to the Annual Report on Form 10-K of O.I. Corporation is being filed solely for the purpose of including the information required by Part III, Items 10-14 of Form 10-K. This information was previously omitted from the Form 10-K in reliance on General Instruction G to Form 10-K which provides that registrants may incorporate by reference certain information from a definitive proxy statement filed with the Securities Exchange Commission within 120 days after the end of the fiscal year. The reference on the cover of the Annual Report on Form 10-K to the incorporation by reference of the registrant's definitive proxy statement into Part III of the Annual Report is hereby deleted. This report is limited in scope to the items identified above and should be read in conjunction with the Original Filing.
# [
#     {
#         "reason": "The note specifically mentions that the purpose of the amendment is to include information required by Part III, Items 10-14 of Form 10-K, which justifies tagging it as Part III.",
#         "tag": "Part III"
#     }
# ]
# ['Part III']
# ------
# ------
# The purpose of this amended Form 10-K is to restate the financial statements for the year ended December 31, 2012 to reflect the proper revenues and related adjustments.
#
# [
#     {
#         "reason": "The note specifically mentions that the purpose of the amendment is to restate the financial statements, which aligns with the definition of Restatements tag.",
#         "tag": "Restatements"
#     }
# ]
# ['Restatements']
# ------
# ------
# The Form 10-Q/A is being filed solely to correct the omission of certain language required under the Certification in the World Monitor Trust II – Series D's Form 10-Q previously filed on August 7, 2008 and amended on February 2, 2009, which are restated in their entirety herewith.
#
# [
#     {
#         "reason": "The note mentions that the Form 10-Q/A is being filed solely to correct the omission of certain language, which indicates that it is an amendment to correct an error.",
#         "tag": "Errors"
#     },
#     {
#         "reason": "The note also states that the Form 10-Q/A is being restated in its entirety, indicating a restatement.",
#         "tag": "Restatements"
#     }
# ]
# ['Errors', 'Restatements']
# ['Errors']
# ['Restatements', 'Errors']
# ------
# ------
# The purpose of this Amendment No. 1 is to add Suneil Parulekar, our Senior Vice President, Worldwide Marketing and Sales, as a named executive officer for purposes of Part III, Item 11 ("Executive Compensation") and the "Security Ownership of Management" table in Item 12 ("Security Ownership of Certain Beneficial Owners and Management and Related Stockholder Matters"). We have also corrected minor typographical and formatting errors.
# [
#     {
#         "reason": "The note mentions amending to add a named executive officer for Part III and correcting minor errors, which aligns with the Part III and Errors tags.",
#         "tag": "Part III"
#     },
#     {
#         "reason": "The note states that minor typographical and formatting errors have been corrected, which justifies the Errors tag.",
#         "tag": "Errors"
#     }
# ]
# ['Part III', 'Errors']
# ['Errors', 'Part III']
# ['Errors', 'Part III']
# ------
# ------
# The registrant is filing this Amendment No. 1 to its Quarterly Report on Form 10-Q for the quarterly period ended June 30, 2008, which was originally filed with the Securities and Exchange Commission ("SEC") on August 19, 2008 ("Original Form 10-Q"), to amend Part 1 Financial Information – Item 1 "Financial Statements" and Item 2 "Management's Discussion and Analysis of Financial Condition and Results of Operations" ("MD&A). Additionally, one typographical error in each of Part 1 Financial Information – Item 4 "Controls and Procedures" and in Part 2 Other Information - Item 1A "Risk Factors" respectively has been corrected.
#
# []
# []
# ['Restatements']
# ['Errors']
# ------
# ------
# The purpose of this Form 10-K/A is to correct the front page of the Form 10-K for the fiscal year ended December 31, 2004, previously filed with the Securities and Exchange Commission. The correction involves the incorrect statement that there were 23,531,229 shares of the registrant's common stock outstanding as of January 31, 2005, when the correct number was 19,261,652 shares.
# [
#     {
#         "reason": "The note mentions that the purpose of the filing is to correct an error in the number of shares of common stock outstanding, which aligns with the definition of the Errors tag.",
#         "tag": "Errors"
#     }
# ]
# ['Errors']
# ------
# ------
# The sole purpose of this Form 10-Q/A is to furnish the interactive data files from our Form 10-Q formatted in Extensible Business Reporting Language (XBRL)
# []
# []
# ['Exhibit 101']
# ['Exhibit 101']
# ------
# ------
# The purpose of this Amendment is to amend and restate the following Items in the Original Report as amended including updating the Title Page:
#
# []
# []
# ['Restatements']
# ['Restatements']
# ------
# ------
# The purpose of this Amendment is to restate the financial statements of FinTech Acquisition Corp. V for the year ended December 31, 2020, to correct an error identified in the Original Financial Statements related to the recording of Class A common stock subject to possible redemption. Management has determined that the shares of Class A common stock underlying the units issued during the initial public offering can be redeemed or become redeemable, leading to a reclassification error between temporary equity and permanent equity. This restatement also includes changes to the earnings per share calculation to allocate income and losses pro rata between the two classes of shares.
#
# [
#     {
#         "reason": "The note mentions that the purpose of the Amendment is to restate the financial statements to correct an error identified in the Original Financial Statements",
#         "tag": "Restatements"
#     },
#     {
#         "reason": "The note specifically states that the restatement is to correct an error related to the recording of Class A common stock, justifying the 'Errors' tag",
#         "tag": "Errors"
#     }
# ]
# ['Restatements', 'Errors']
# ['Restatements']
# ['Restatements', 'Errors']
# ------
# ------
# The purpose of this Amendment No. 2 on Form 10-Q/A to the Original Form 10-Q (the "Amendment No. 2") (i) includes the entire periodic report originally filed with the Original Form 10-Q, (ii) amends and restates Note 4 (Private Placement) of the Notes to the Company's Condensed Financial Statements included therein and (iii) includes updated certifications by our Chief Executive Officer and Chief Financial Officer as required by Item 601 of Regulation S-K.
#
# [
#     {
#         "reason": "The note mentions amending and restating Note 4 of the financial statements, which indicates a restatement.",
#         "tag": "Restatements"
#     }
# ]
# ['Restatements']
# ------
# ------
# Accordingly, this amended 10-Q is filed to correct the manner in which the Company accounted for the lease. See Note I. Restatement, to the accompanying financial statements, for further information.
# [
#     {
#         "reason": "The note mentions that the amended 10-Q is filed to correct the manner in which the Company accounted for the lease, indicating a restatement of financial statements.",
#         "tag": "Restatements"
#     }
# ]
# ['Restatements']
# ------
# ------
# The purpose of this Amendment No. 1 on Form 10-K/A is to provide the information required by Part III of Form 10-K, which was previously omitted from the Original Filing in reliance on General Instruction G(3) to Form 10-K. Additionally, this Form 10-K/A amends and restates specific items in their entirety as required by Rule 12b-15 under the Exchange Act of 1934.
#
# [
#     {
#         "reason": "The note mentions amending and restating specific items in their entirety as required by Rule 12b-15 under the Exchange Act of 1934, which indicates a restatement.",
#         "tag": "Restatements"
#     },
#     {
#         "reason": "The note states that the purpose of the amendment is to provide the information required by Part III of Form 10-K, which was previously omitted from the Original Filing, indicating a need to include information in Part III.",
#         "tag": "Part III"
#     }
# ]
# ['Restatements', 'Part III']
# ['Part III']
# ['Restatements', 'Part III']
# ------
# ------
# The Company is filing this Amendment No. 3 to its Form 10Q for the fiscal quarter ended June 30, 2011 originally filed with the Securities and Exchange Commission on August 19, 2011 (the "Original Filing") and subsequently amended on September 14, 2011, and March 23, 2012. As previously reported by the Company on a Form 8-K filed with the Commission on September 20, 2012, on September 19, 2012, the Company changed its fiscal year end from March 31st to December 31st, commencing on December 31, 2012. Prior to this change, the Company's subsidiaries, with the exception of SD Holdings, Ltd. had a December 31st fiscal year end and in reporting the Company's financial statements, the Company, incorrectly applied of Rule 3A-02 ("the 93-day rule") promulgated under Regulation S-X by consolidating those subsidiaries without any adjustments for
#
# []
# []
# ['Restatements']
# ['None of the above']
# ------
# ------
# The purpose of this Amendment No. 2 to the Annual Report on Form 10-K of Oaktree Acquisition Corp. II is to restate certain items in its previous filings, specifically related to the accounting classification of its outstanding Class A ordinary shares issued as part of the initial public offering. The Company has re-evaluated its application of ASC 480-10-S99-3A and determined that all of the Public Shares should be classified as temporary equity, leading to a restatement of earnings per share calculation to allocate income and losses pro rata between the two classes of shares.
#
# [
#     {
#         "reason": "The note mentions that the purpose of the amendment is to restate certain items in its previous filings related to accounting classification, leading to a restatement of earnings per share calculation. This aligns with the definition of restatements.",
#         "tag": "Restatements"
#     }
# ]
# ['Restatements']
# ------
# ------
# The purpose of this Amendment No. 1 to Bonds.com Group, Inc.'s annual report filed on Form 10-K/A is to correct the Company's inadvertent omission of a portion of the execution dates in the Certifications previously filed.
# [
#     {
#         "reason": "The note mentions that the purpose of the filing is to correct an error, which is the inadvertent omission of a portion of the execution dates in the Certifications previously filed.",
#         "tag": "Errors"
#     }
# ]
# ['Errors']
# ------
# ------
# The purpose of this Amendment No. 1 to the Annual Report of Meganet Corporation (the "Company") on Form 10-K for the fiscal year ended March 31, 2013, filed with the Securities and Exchange Commission on September 11, 2014 (the "Form 10-K"), is to furnish Exhibit 101 to the Form 10-K in accordance with Rule 405 of Regulation S-T. Exhibit 101 to this report provides the financial statements and related notes from the Form 10-K formatted in XBRL (eXtensible Business Reporting Language).
# []
# []
# ['Exhibit 101']
# ['Exhibit 101']
# ------
# ------
# The sole purpose of this Amendment to the Registrant's Quarterly Report on Form 10-Q for the period ended March 31, 2012 (the "10-Q"), is to furnish the Interactive Data File exhibits required by Item 601(b)(101) of Regulation S-K. No other changes have been made to the 10-Q, and this Amendment has not been updated to reflect events occurring subsequent to the filing of the 10-Q.
# [
#     {
#         "reason": "The note is specifically mentioning that the purpose of the amendment is to furnish Exhibit 101, which is required by Item 601(b)(101) of Regulation S-K.",
#         "tag": "Exhibit 101"
#     }
# ]
# ['Exhibit 101']
# ------
# ------
# The purpose of this amendment is to amend and restate Part I, Items 1 and 2 "Financial Information" and Part II, Item 6 "Exhibits and Reports on Form 8-K" of the Form 10-Q as a result of a restatement of the Company's balance sheet and operating results for the year ended December 31, 1998. This restatement is to reduce acquisition-related reserves and charges by $31.0 million and provide additional disclosures related to the Company's 1998 acquisition of Howmedica, following discussions with the Securities and Exchange Commission ("SEC").
# [
#     {
#         "reason": "The note mentions a restatement of the Company's balance sheet and operating results for the year ended December 31, 1998",
#         "tag": "Restatements"
#     }
# ]
# ['Restatements']
# ------

# %%
df_sampled
# Out:
#                       file_name  \
# 536  q_0001193125-12-359187.txt
# 501  k_0001214659-15-003301.txt
# 36   k_0001144204-09-022929.txt
# 884  k_0001548123-13-000255.txt
# 902  q_0001193125-09-016547.txt
# 35   k_0000070530-10-000086.txt
# 895  q_0001144204-08-051465.txt
# 296  k_0001035704-05-000135.txt
# 522  q_0001213900-11-005101.txt
# 822  q_0001144204-10-011777.txt
# 820  k_0001213900-21-062647.txt
# 897  q_0001193125-23-066323.txt
# 714  q_0001654954-17-011499.txt
# 824  k_0000950123-09-009972.txt
# 839  q_0001144204-13-039769.txt
# 752  k_0001193125-21-355379.txt
# 484  k_0001144204-08-035768.txt
# 629  k_0000939798-15-000029.txt
# 524  q_0001324344-12-000004.txt
# 705  q_0000310764-00-000007.txt
#
#                                          expl_note_gpt              labels  \
# 536  The paragraph that talks about the purpose of ...       [Exhibit 101]
# 501  The purpose of this Form 10-K/A is to provide ...          [Part III]
# 36   The purpose of this Amendment No. 1 on Form 10...          [Part III]
# 884  The purpose of this amended Form 10-K is to re...      [Restatements]
# 902  The Form 10-Q/A is being filed solely to corre...            [Errors]
# 35   The purpose of this Amendment No. 1 is to add ...  [Errors, Part III]
# 895  The registrant is filing this Amendment No. 1 ...      [Restatements]
# 296  The purpose of this Form 10-K/A is to correct ...            [Errors]
# 522  The sole purpose of this Form 10-Q/A is to fur...       [Exhibit 101]
# 822  The purpose of this Amendment is to amend and ...      [Restatements]
# 820  The purpose of this Amendment is to restate th...      [Restatements]
# 897  The purpose of this Amendment No. 2 on Form 10...      [Restatements]
# 714  Accordingly, this amended 10-Q is filed to cor...      [Restatements]
# 824  The purpose of this Amendment No. 1 on Form 10...          [Part III]
# 839  The Company is filing this Amendment No. 3 to ...      [Restatements]
# 752  The purpose of this Amendment No. 2 to the Ann...      [Restatements]
# 484  The purpose of this Amendment No. 1 to Bonds.c...            [Errors]
# 629  The purpose of this Amendment No. 1 to the Ann...       [Exhibit 101]
# 524  The sole purpose of this Amendment to the Regi...       [Exhibit 101]
# 705  The purpose of this amendment is to amend and ...      [Restatements]
#
#                                              expl_note  \
# 536  EXPLANATORY NOTE  This Amendment No. 1 to the ...
# 501  EXPLANATORY NOTE\n\n Wright Investors' Service...
# 36   EXPLANATORY\nNOTE\n\nThis\nAmendment No. 1 on ...
# 884  EXPLANATORY NOTE  During the preparation of th...
# 902  Explanatory Note  The Form 10-Q/A is being fil...
# 35   EXPLANATORY NOTE\n\nWe are filing this Amendme...
# 895  Explanatory\n      Note\n\nThe\n      registra...
# 296  EXPLANATORY NOTE\nSIGNATURES\nEXHIBIT INDEX\nC...
# 522  EXPLANATORY NOTE\n\n The sole purpose of this ...
# 822  EXPLANATORY\nNOTE\n\n    EGPI\nFirecreek, Inc....
# 820  EXPLANATORY NOTE \n\n FinTech Acquisition Corp...
# 897  EXPLANATORY NOTE \nThe Company's Quarterly Rep...
# 714  EXPLANATORY NOTE\n\nIn October 2008, the Compa...
# 824  Explanatory Note\n\nThis Amendment No. 1 on Fo...
# 839  EXPLANATORY NOTE\n\nThe Company is filing this...
# 752  EXPLANATORY NOTE \n\n Oaktree Acquisition Corp...
# 484  EXPLANATORY\n        NOTE\n\nThis\n        Ame...
# 629  EXPLANATORY NOTE\n\nThe purpose of this Amendm...
# 524  EXPLANATORY NOTE\n\nThe sole purpose of this A...
# 705  EXPLANATORY NOTE\n\n\tThis Amendment No. 1 on ...
#
#              rule_based_label                labels_gpt  \
# 536             [Exhibit 101]             [Exhibit 101]
# 501                [Part III]                [Part III]
# 36                 [Part III]                [Part III]
# 884            [Restatements]            [Restatements]
# 902    [Restatements, Errors]    [Errors, Restatements]
# 35         [Errors, Part III]                [Part III]
# 895                  [Errors]                        []
# 296                  [Errors]                  [Errors]
# 522             [Exhibit 101]                        []
# 822            [Restatements]                        []
# 820    [Restatements, Errors]    [Restatements, Errors]
# 897            [Restatements]            [Restatements]
# 714    [Restatements, Errors]            [Restatements]
# 824  [Restatements, Part III]  [Part III, Restatements]
# 839       [None of the above]                        []
# 752            [Restatements]            [Restatements]
# 484                  [Errors]                  [Errors]
# 629             [Exhibit 101]                        []
# 524       [None of the above]             [Exhibit 101]
# 705            [Restatements]            [Restatements]
#
#                   labels_gpt3              labels_gpt4o  \
# 536             [Exhibit 101]             [Exhibit 101]
# 501                        []   [Part III, Exhibit 101]
# 36                 [Part III]                [Part III]
# 884            [Restatements]            [Restatements]
# 902    [Errors, Restatements]    [Errors, Restatements]
# 35         [Part III, Errors]        [Part III, Errors]
# 895                        []                        []
# 296                  [Errors]                        []
# 522                        []                        []
# 822                        []                        []
# 820    [Restatements, Errors]    [Restatements, Errors]
# 897            [Restatements]                        []
# 714            [Restatements]            [Restatements]
# 824  [Restatements, Part III]  [Restatements, Part III]
# 839                        []                        []
# 752            [Restatements]            [Restatements]
# 484                        []                  [Errors]
# 629             [Exhibit 101]             [Exhibit 101]
# 524             [Exhibit 101]             [Exhibit 101]
# 705            [Restatements]            [Restatements]
#
#                   labels_gpt4
# 536             [Exhibit 101]
# 501                        []
# 36                 [Part III]
# 884            [Restatements]
# 902    [Errors, Restatements]
# 35         [Part III, Errors]
# 895                        []
# 296                  [Errors]
# 522                        []
# 822                        []
# 820    [Restatements, Errors]
# 897                        []
# 714            [Restatements]
# 824  [Restatements, Part III]
# 839                        []
# 752            [Restatements]
# 484                        []
# 629                        []
# 524             [Exhibit 101]
# 705            [Restatements]

# %%
labels_gpt_3_encoded = mlb.transform(df_sampled['labels_gpt3'])
labels_gpt_4o_encoded = mlb.transform(df_sampled['labels_gpt4o'])
labels_gpt_4_encoded = mlb.transform(df_sampled['labels_gpt4'])
labels_rule_based_encoded = mlb.transform(df_sampled['rule_based_label'])
labels_encoded = mlb.transform(df_sampled['labels'])
# Out:
# /Users/ihjasahammedm/miniconda3/envs/hf/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:900: UserWarning: unknown class(es) ['None of the above'] will be ignored
#   warnings.warn(

# %%
types = ['Rule Based', 'GPT-3.5', 'GPT-4o', 'GPT-4']
label4types = [labels_rule_based_encoded, labels_gpt_3_encoded, labels_gpt_4o_encoded, labels_gpt_4_encoded]
for i, type in enumerate(types):
    print(f"-----------{type}------------")
    print('Accuracy:', accuracy_score(labels_encoded, label4types[i]))
    print('Classification Report:')
    print(classification_report(labels_encoded, label4types[i], target_names=mlb.classes_))
# Out:
# -----------Rule Based------------
# Accuracy: 0.65
# Classification Report:
#               precision    recall  f1-score   support
#
#       Errors       0.57      1.00      0.73         4
#  Exhibit 101       1.00      0.75      0.86         4
#     Part III       1.00      1.00      1.00         4
# Restatements       0.78      0.78      0.78         9
#
#    micro avg       0.78      0.86      0.82        21
#    macro avg       0.84      0.88      0.84        21
# weighted avg       0.82      0.86      0.83        21
#  samples avg       0.75      0.85      0.78        21
#
# -----------GPT-3.5------------
# Accuracy: 0.45
# Classification Report:
#               precision    recall  f1-score   support
#
#       Errors       0.75      0.75      0.75         4
#  Exhibit 101       1.00      0.50      0.67         4
#     Part III       1.00      0.75      0.86         4
# Restatements       0.71      0.56      0.62         9
#
#    micro avg       0.81      0.62      0.70        21
#    macro avg       0.87      0.64      0.72        21
# weighted avg       0.83      0.62      0.70        21
#  samples avg       0.53      0.60      0.55        21
#
# -----------GPT-4o------------
# Accuracy: 0.5
# Classification Report:
#               precision    recall  f1-score   support
#
#       Errors       0.75      0.75      0.75         4
#  Exhibit 101       0.75      0.75      0.75         4
#     Part III       1.00      1.00      1.00         4
# Restatements       0.71      0.56      0.62         9
#
#    micro avg       0.79      0.71      0.75        21
#    macro avg       0.80      0.76      0.78        21
# weighted avg       0.78      0.71      0.74        21
#  samples avg       0.60      0.70      0.63        21
#
# -----------GPT-4------------
# Accuracy: 0.55
# Classification Report:
#               precision    recall  f1-score   support
#
#       Errors       0.80      1.00      0.89         4
#  Exhibit 101       1.00      0.50      0.67         4
#     Part III       1.00      0.75      0.86         4
# Restatements       0.75      0.67      0.71         9
#
#    micro avg       0.83      0.71      0.77        21
#    macro avg       0.89      0.73      0.78        21
# weighted avg       0.85      0.71      0.76        21
#  samples avg       0.62      0.70      0.65        21
# /Users/ihjasahammedm/miniconda3/envs/hf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/ihjasahammedm/miniconda3/envs/hf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/ihjasahammedm/miniconda3/envs/hf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/ihjasahammedm/miniconda3/envs/hf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
types = ['Rule Based', 'GPT-3.5', 'GPT-4o', 'GPT-4']
label4types = [labels_rule_based_encoded, labels_gpt_3_encoded, labels_gpt_4o_encoded, labels_gpt_4_encoded]
for i, type in enumerate(types):
    print(f"-----------{type}------------")
    print('Accuracy:', accuracy_score(labels_rule_based_encoded, label4types[i]))
    print('Classification Report:')
    print(classification_report(labels_rule_based_encoded, label4types[i], target_names=mlb.classes_))
# Out:
# -----------Rule Based------------
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#       Errors       1.00      1.00      1.00         7
#  Exhibit 101       1.00      1.00      1.00         3
#     Part III       1.00      1.00      1.00         4
# Restatements       1.00      1.00      1.00         9
#
#    micro avg       1.00      1.00      1.00        23
#    macro avg       1.00      1.00      1.00        23
# weighted avg       1.00      1.00      1.00        23
#  samples avg       0.90      0.90      0.90        23
#
# -----------GPT-3.5------------
# Accuracy: 0.55
# Classification Report:
#               precision    recall  f1-score   support
#
#       Errors       1.00      0.57      0.73         7
#  Exhibit 101       0.50      0.33      0.40         3
#     Part III       1.00      0.75      0.86         4
# Restatements       1.00      0.78      0.88         9
#
#    micro avg       0.94      0.65      0.77        23
#    macro avg       0.88      0.61      0.71        23
# weighted avg       0.93      0.65      0.76        23
#  samples avg       0.55      0.53      0.53        23
#
# -----------GPT-4o------------
# Accuracy: 0.6
# Classification Report:
#               precision    recall  f1-score   support
#
#       Errors       1.00      0.57      0.73         7
#  Exhibit 101       0.50      0.67      0.57         3
#     Part III       1.00      1.00      1.00         4
# Restatements       1.00      0.78      0.88         9
#
#    micro avg       0.89      0.74      0.81        23
#    macro avg       0.88      0.75      0.79        23
# weighted avg       0.93      0.74      0.81        23
#  samples avg       0.62      0.62      0.62        23
#
# -----------GPT-4------------
# Accuracy: 0.65
# Classification Report:
#               precision    recall  f1-score   support
#
#       Errors       1.00      0.71      0.83         7
#  Exhibit 101       0.50      0.33      0.40         3
#     Part III       1.00      0.75      0.86         4
# Restatements       1.00      0.89      0.94         9
#
#    micro avg       0.94      0.74      0.83        23
#    macro avg       0.88      0.67      0.76        23
# weighted avg       0.93      0.74      0.82        23
#  samples avg       0.65      0.62      0.63        23
# /Users/ihjasahammedm/miniconda3/envs/hf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/ihjasahammedm/miniconda3/envs/hf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/ihjasahammedm/miniconda3/envs/hf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in samples with no true nor predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/ihjasahammedm/miniconda3/envs/hf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/ihjasahammedm/miniconda3/envs/hf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/ihjasahammedm/miniconda3/envs/hf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in samples with no true nor predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/ihjasahammedm/miniconda3/envs/hf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/ihjasahammedm/miniconda3/envs/hf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/ihjasahammedm/miniconda3/envs/hf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in samples with no true nor predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/ihjasahammedm/miniconda3/envs/hf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/ihjasahammedm/miniconda3/envs/hf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/ihjasahammedm/miniconda3/envs/hf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in samples with no true nor predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
